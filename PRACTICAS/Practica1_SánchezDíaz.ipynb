# %% [markdown]
# **Práctica 1: Análisis exploratorio de datos**
#
# Nombre: Sánchez Díaz María Beatriz
#
# Email: bety.sanchez.diaz@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
DatosMelbourne = pd.read_csv('/content/sample_data/melb_data.csv')

# %%
DatosMelbourne
# Out:
#               Suburb  ... Propertycount
# 0         Abbotsford  ...        4019.0
# 1         Abbotsford  ...        4019.0
# 2         Abbotsford  ...        4019.0
# 3         Abbotsford  ...        4019.0
# 4         Abbotsford  ...        4019.0
# ...              ...  ...           ...
# 13575  Wheelers Hill  ...        7392.0
# 13576   Williamstown  ...        6380.0
# 13577   Williamstown  ...        6380.0
# 13578   Williamstown  ...        6380.0
# 13579     Yarraville  ...        6543.0
#
# [13580 rows x 21 columns]

# %% [markdown]
# Paso 1. Descripción de la estructura de los datos

# %%
DatosMelbourne.shape
# Out:
# (13580, 21)

# %%
DatosMelbourne.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
DatosMelbourne.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# **Paso 2. Identificación de datos faltantes**

# %%
DatosMelbourne.info
# Out:
# <bound method DataFrame.info of               Suburb  ... Propertycount
# 0         Abbotsford  ...        4019.0
# 1         Abbotsford  ...        4019.0
# 2         Abbotsford  ...        4019.0
# 3         Abbotsford  ...        4019.0
# 4         Abbotsford  ...        4019.0
# ...              ...  ...           ...
# 13575  Wheelers Hill  ...        7392.0
# 13576   Williamstown  ...        6380.0
# 13577   Williamstown  ...        6380.0
# 13578   Williamstown  ...        6380.0
# 13579     Yarraville  ...        6543.0
#
# [13580 rows x 21 columns]>

# %% [markdown]
# **Paso 3. Detección de valores atípicos**

# %%
DatosMelbourne.hist(figsize=(14,14), xrot=45)
plt.show()

# %%
DatosMelbourne.describe()
# Out:
#               Rooms         Price  ...    Longtitude  Propertycount
# count  13580.000000  1.358000e+04  ...  13580.000000   13580.000000
# mean       2.937997  1.075684e+06  ...    144.995216    7454.417378
# std        0.955748  6.393107e+05  ...      0.103916    4378.581772
# min        1.000000  8.500000e+04  ...    144.431810     249.000000
# 25%        2.000000  6.500000e+05  ...    144.929600    4380.000000
# 50%        3.000000  9.030000e+05  ...    145.000100    6555.000000
# 75%        3.000000  1.330000e+06  ...    145.058305   10331.000000
# max       10.000000  9.000000e+06  ...    145.526350   21650.000000
#
# [8 rows x 13 columns]

# %%
variables = ['Price','Landsize', 'BuildingArea', 'YearBuilt']

for col in variables:
    sns.boxplot(col, data= DatosMelbourne)
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# Observaciones 1) 2) 3) 4)
#
# 2)Caracteristicas nominales

# %%
DatosMelbourne.describe(include='object')
# Out:
#            Suburb           Address  ... CouncilArea             Regionname
# count       13580             13580  ...       12211                  13580
# unique        314             13378  ...          33                      8
# top     Reservoir  1/1 Clarendon St  ...    Moreland  Southern Metropolitan
# freq          359                 3  ...        1163                   4695
#
# [4 rows x 8 columns]

# %%
DatosMelbourne.describe(include='object')
# Out:
#            Suburb           Address  ... CouncilArea             Regionname
# count       13580             13580  ...       12211                  13580
# unique        314             13378  ...          33                      8
# top     Reservoir  1/1 Clarendon St  ...    Moreland  Southern Metropolitan
# freq          359                 3  ...        1163                   4695
#
# [4 rows x 8 columns]

# %%
for col in DatosMelbourne.select_dtypes(include='object'):
    if DatosMebourne[col].nunique()<10:sns.countplot(y=col, data=DatosMebourne)
    plt.show()

# %%
for col in DatosMelbourne.select_dtypes(include=object):
    if DatosMelbourne[col].nunique() <10:
        display(DatosMebourne.groupby(col).agg(['mean']))
# Out:
#          Rooms         Price   Distance  ...  Lattitude  Longtitude Propertycount
#           mean          mean       mean  ...       mean        mean          mean
# Type                                     ...
# h     3.260874  1.242665e+06  10.979479  ... -37.803795  144.994700   7259.025505
# t     2.837522  9.337351e+05   9.851346  ... -37.815782  144.996489   7094.459605
# u     1.963871  6.051275e+05   7.607391  ... -37.823710  144.996363   8199.280080
#
# [3 rows x 13 columns]
#            Rooms         Price   Distance  ...  Lattitude  Longtitude Propertycount
#             mean          mean       mean  ...       mean        mean          mean
# Method                                     ...
# PI      3.077366  1.133242e+06   9.482097  ... -37.814429  145.001865   7749.644501
# S       2.941809  1.087327e+06  10.431523  ... -37.808204  144.997012   7496.049435
# SA      3.010870  1.025772e+06  12.385870  ... -37.818112  145.023262   6945.902174
# ...

# %% [markdown]
# **Paso 4. Identificación de relaciones entre variables**

# %%
DatosMelbourne.corr()
# Out:
#                   Rooms     Price  ...  Longtitude  Propertycount
# Rooms          1.000000  0.496634  ...    0.100771      -0.081530
# Price          0.496634  1.000000  ...    0.203656      -0.042153
# Distance       0.294203 -0.162522  ...    0.239425      -0.054910
# Postcode       0.055303  0.107867  ...    0.445357       0.062304
# Bedroom2       0.944190  0.475951  ...    0.102238      -0.081350
# Bathroom       0.592934  0.467038  ...    0.118971      -0.052201
# Car            0.408483  0.238979  ...    0.063395      -0.024295
# Landsize       0.025678  0.037507  ...    0.010833      -0.006854
# BuildingArea   0.124127  0.090981  ...   -0.023810      -0.028840
# YearBuilt     -0.065413 -0.323617  ...   -0.003470       0.006361
# Lattitude      0.015948 -0.212934  ...   -0.357634       0.047086
# Longtitude     0.100771  0.203656  ...    1.000000       0.065988
# Propertycount -0.081530 -0.042153  ...    0.065988       1.000000
#
# [13 rows x 13 columns]

# %%
plt.figure(figsize=(14,14))
sns.heatmap(DatosMelbourne.corr(), cmap='RdBu_r', annot=True)
plt.show()
